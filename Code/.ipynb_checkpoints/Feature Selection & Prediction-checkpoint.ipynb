# %% [markdown]
# ### Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_selection import SelectKBest, chi2, f_regression
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler, PolynomialFeatures

from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold, train_test_split
from sklearn.linear_model import Ridge, Lasso, LinearRegression

# %%
path_ = "c:/Users/Paul/Desktop/MSc DSBA/1. Big Data Analytics/1. Project/Full Data/Cleaned Data/"

# %% [markdown]
# ### Loading data

# %%
df = pd.read_csv(path_+'featured_daily_data.csv')

# %%
df.head()
# Out:
#    year  month  day  year.1       index  max_temp  min_temp  wind_speed  \
# 0  2010      9   15    2010  2010-09-15      29.0      17.0    2.222222
# 1  2010      9   16    2010  2010-09-16      31.0      17.0    4.444444
# 2  2010      9   17    2010  2010-09-17      25.0      18.0    4.166667
# 3  2010      9   19    2010  2010-09-19      29.0      16.0    1.388889
# 4  2010      9   20    2010  2010-09-20      25.0      16.0    5.000000
#
#    wind_temp      rain    ...      wkday_cos  sunrise_sin  sunrise_cos  \
# 0       17.0  0.000000    ...      -0.900969     0.965926     0.258819
# 1       17.0  1.000000    ...      -0.900969     0.965926     0.258819
# 2       18.0  2.000000    ...      -0.222521     0.965926     0.258819
# 3       16.0  7.666667    ...       0.623490     0.965926     0.258819
# 4       16.0  7.666667    ...       1.000000     0.965926     0.258819
#
#    sunset_sin    sunset_cos  mnth_sin  mnth_cos  light  missing_rain  \
# 0        -1.0 -1.836970e-16 -0.866025      -0.5   13.0         False
# 1        -1.0 -1.836970e-16 -0.866025      -0.5   13.0         False
# 2        -1.0 -1.836970e-16 -0.866025      -0.5   13.0         False
# 3        -1.0 -1.836970e-16 -0.866025      -0.5   13.0          True
# 4        -1.0 -1.836970e-16 -0.866025      -0.5   13.0          True
#
#    mean_rain
# 0   7.666667
# 1   7.666667
# 2   7.666667
# 3   7.666667
# 4   7.666667
#
# [5 rows x 39 columns]

# %% [markdown]
# ### Setting index

# %%
df['index'] = pd.to_datetime(df['index'])
df = df.set_index('index', drop = True)

# %%
data = df

# %%
df_targets = data['cnt']

# %%
df = data.drop(['cnt', 'registered', 'casual', 'string_date', 'month','year', 'day'], axis = 1)

# %%
mm = MinMaxScaler()
df = mm.fit_transform(df)

pf = PolynomialFeatures(degree = 3)
df = pf.fit_transform(df)

print(df.shape)
mm_targets = MinMaxScaler()
df_targets = mm_targets.fit_transform(df_targets.values.astype(float).reshape(-1,1))
# Out:
# (2171, 5984)

# %%
#selecting_features = SelectKBest(chi2, k=15).fit(df, df_targets)
#pca = PCA(n_components=15).fit(df)

# %%
#df_best = selecting_features.transform(df)
#df_best = pca.transform(df)
df_best = df

# %%
k_fold = KFold(n_splits=10)

# %%
scores_ridge = []
scores_lasso = []
scores_ridge_train = []
scores_lasso_train = []
scores_rf = []
scores_rf_train = []


for train_index, test_index in k_fold.split(df_best):
    
    X_train = df_best[train_index, :]
    y_train = df_targets[train_index]
    X_test = df_best[test_index, :]
    y_test = df_targets[test_index]
    
    ridge = Ridge()
    lasso = Lasso()
    rf = RandomForestRegressor(n_estimators=100, max_depth=3)
    
    
    ridge.fit(X_train,y_train)
    lasso.fit(X_train, y_train)
    #rf.fit(X_train, y_train)
    
    scores_ridge.append(mean_squared_error(y_test, ridge.predict(X_test)))
    scores_lasso.append(mean_squared_error(y_test, lasso.predict(X_test)))
    #scores_rf.append(mean_squared_error(y_test, rf.predict(X_test)))
    #scores_rf_train.append(mean_squared_error(y_train, rf.predict(X_train)))
    scores_ridge_train.append(mean_squared_error(y_train, ridge.predict(X_train)))
    scores_lasso_train.append(mean_squared_error(y_train, lasso.predict(X_train)))

# %% [markdown]
# ### Training models

# %%
X_train, X_test, y_train, y_test = train_test_split(df_best, df_targets, test_size = .2)
X_train, X_cv, y_train, y_cv = train_test_split(X_train, y_train, test_size = .2)

# %% [markdown]
# #### Linear Regression

# %%
model = LinearRegression()
model.fit(X_train, y_train)
training_score = mean_squared_error(y_train, model.predict(X_train))
y_pred_cv = model.predict(X_cv)
cross_val_score = mean_squared_error(y_cv, y_pred_cv)
print('Training score {}'.format(training_score))
print('Cross-Validation {}'.format(cross_val_score))
# Out:
# Training score 1.8013583457294635e-28
# Cross-Validation 0.04263009410291294

# %% [markdown]
# #### Lasso Regularization

# %%
model = Lasso()
model.fit(X_train, y_train)
training_score = mean_squared_error(y_train, model.predict(X_train))
y_pred_cv = model.predict(X_cv)
cross_val_score = mean_squared_error(y_cv, y_pred_cv)
print('Training score {}'.format(training_score))
print('Cross-Validation {}'.format(cross_val_score))
# Out:
# Training score 0.04777756133618253
# Cross-Validation 0.0508366289264992

# %% [markdown]
# #### Ridge Regression

# %%
model = Ridge()
model.fit(X_train, y_train)
training_score = mean_squared_error(y_train, model.predict(X_train))
y_pred_cv = model.predict(X_cv)
cross_val_score = mean_squared_error(y_cv, y_pred_cv)
print('Training score {}'.format(training_score))
print('Cross-Validation {}'.format(cross_val_score))
# Out:
# Training score 0.0018144477495030261
# Cross-Validation 0.00418938789693714

# %%
actual_predictions = mm_targets.inverse_transform(y_pred_cv)
actual_values = mm_targets.inverse_transform(y_cv)

actual_error = mean_squared_error(actual_predictions, actual_values)

print("Mean prediction error {}".format(actual_error))
# Out:
# Mean prediction error 1039757.9650891898

# %%
relative_error = np.abs(np.array(actual_values-actual_predictions)/np.array(actual_values))

plt.figure(figsize = (16,8))
plt.hist(relative_error, bins=200, range=(0, 1))
plt.axvline(.05, color = 'r')
#plt.axvline(-.05, color = 'r')
plt.xlabel("Relative Error")
plt.show()
print(np.mean(relative_error))
# Out:
# 0.217537766998

# %% [markdown]
# ### Deep Learning

# %%
import tensorflow as tf

# %%
import keras.backend as K

# %%
from keras.models import Sequential 
from keras.layers import Dense, Dropout, LSTM
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau, EarlyStopping

# %%
K.clear_session()
model = Sequential()
reduce = ReduceLROnPlateau(monitor='val_loss', factor=.1, patience = 10, verbose = 1)
early = EarlyStopping(monitor='val_loss', patience = 1000, min_delta=0, verbose = 1)

model.add(Dense(10, input_shape = (X_train.shape[1], ), activation = 'relu'))
model.add(Dense(10, activation = 'relu'))
model.add(Dense(5, activation = 'relu'))
model.add(Dense(1))

model.summary()

model.compile(optimizer = Adam(lr = .0001), loss = 'mse')

_ = model.fit(df_best, df_targets, batch_size=512, epochs=10000, validation_split=.3, verbose = 0, callbacks=[reduce, early])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 10)                59850
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 55
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 60,021
# Trainable params: 60,021
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 00026: reducing learning rate to 9.999999747378752e-06.
#
# Epoch 00036: reducing learning rate to 9.999999747378752e-07.
#
# Epoch 00980: reducing learning rate to 9.999999974752428e-08.
#
# Epoch 00995: reducing learning rate to 1.0000000116860975e-08.
#
# Epoch 01005: reducing learning rate to 9.999999939225292e-10.
#
# Epoch 01015: reducing learning rate to 9.999999717180686e-11.
#
# Epoch 01025: reducing learning rate to 9.99999943962493e-12.
#
# Epoch 01035: reducing learning rate to 9.999999092680235e-13.
#
# Epoch 01045: reducing learning rate to 9.9999988758398e-14.
#
# Epoch 01055: reducing learning rate to 9.999999146890344e-15.
#
# Epoch 01065: reducing learning rate to 9.999998977483753e-16.
#
# Epoch 01075: reducing learning rate to 9.999998977483754e-17.
#
# Epoch 01085: reducing learning rate to 9.999998845134856e-18.
#
# Epoch 01095: reducing learning rate to 9.999999010570977e-19.
#
# Epoch 01105: reducing learning rate to 9.999999424161285e-20.
#
# Epoch 01115: reducing learning rate to 9.999999682655225e-21.
#
# Epoch 01125: reducing learning rate to 9.999999682655225e-22.
#
# Epoch 01135: reducing learning rate to 9.999999682655225e-23.
#
# Epoch 01145: reducing learning rate to 9.999999682655227e-24.
#
# Epoch 01155: reducing learning rate to 9.999999998199588e-25.
#
# Epoch 01165: reducing learning rate to 1.0000000195414814e-25.
#
# Epoch 01175: reducing learning rate to 1.0000000195414814e-26.
#
# Epoch 01185: reducing learning rate to 9.999999887266024e-28.
#
# Epoch 01195: reducing learning rate to 1.0000000272452012e-28.
#
# Epoch 01205: reducing learning rate to 1.0000000031710769e-29.
#
# Epoch 01215: reducing learning rate to 1.0000000031710769e-30.
#
# Epoch 01225: reducing learning rate to 1.000000003171077e-31.
#
# Epoch 01235: reducing learning rate to 9.999999796611899e-33.
#
# Epoch 01245: reducing learning rate to 9.999999502738312e-34.
#
# Epoch 01255: reducing learning rate to 9.999999319067318e-35.
#
# Epoch 01265: reducing learning rate to 9.999999319067319e-36.
#
# Epoch 01275: reducing learning rate to 9.999999462560281e-37.
#
# Epoch 01285: reducing learning rate to 9.99999946256028e-38.
#
# Epoch 01295: reducing learning rate to 9.99999991097579e-39.
#
# Epoch 01305: reducing learning rate to 9.999999350456405e-40.
#
# Epoch 01315: reducing learning rate to 1.0000002153053334e-40.
#
# Epoch 01325: reducing learning rate to 9.99994610111476e-42.
#
# Epoch 01335: reducing learning rate to 9.999665841421895e-43.
#
# Epoch 01345: reducing learning rate to 1.0005271035279195e-43.
#
# Epoch 01355: reducing learning rate to 9.949219096706202e-45.
#
# Epoch 01365: reducing learning rate to 9.80908925027372e-46.
#
# Epoch 01375: reducing learning rate to 1.4012984643248171e-46.
# Epoch 02024: early stopping

# %%
print(mean_squared_error(model.predict(X_train), y_train))
test_predictions = model.predict(X_train)
actual_predictions = np.floor(mm_targets.inverse_transform(test_predictions))
actual_values = mm_targets.inverse_transform(y_train)
# Out:
# 0.0237010527619

# %%
relative_error = np.abs(np.array(actual_values-actual_predictions)/np.array(actual_values))

plt.figure(figsize = (16,8))
plt.hist(relative_error, bins=200)#, range=(0, 1))
plt.axvline(.05, color = 'r')
#plt.axvline(-.05, color = 'r')
plt.xlabel("Relative Error")
plt.show()
print(np.mean(relative_error))
# Out:
# 9.0944281693

# %%
plt.figure(figsize = (16,8))
plt.plot(actual_values[-50:])
plt.plot(actual_predictions[-50:])
plt.legend(['actual', 'predictions'])
plt.show()

# %%
plt.figure(figsize = (16,8))
plt.plot(actual_predictions-actual_values)
plt.show()

# %%
np.min(actual_predictions)
# Out:
# 1298.0

# %%
np.min(actual_values)
# Out:
# 9.0

# %%
np.max(actual_predictions)
# Out:
# 13405.0

# %%
np.max(actual_values)
# Out:
# 15755.000000000002
